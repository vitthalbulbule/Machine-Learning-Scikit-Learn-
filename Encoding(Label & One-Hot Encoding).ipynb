# %%
from sklearn.preprocessing import LabelEncoder

# %%
import pandas as pd

# %%
df=pd.read_csv('Simple.csv')
df.head()
# Out:
#     Name  Age  Gender       City Adult
# 0    Ram   56    male     mumbai   yes
# 1  Shyam   12    male      delhi    no
# 2  Lalit   30  female   parbhani   yes
# 3    Raj   20    male  Banghlore   yes
# 4   Ramu   15  female  Banghlore    no

# %%
le=LabelEncoder()
df['Gender_Encode']=le.fit_transform(df['Gender'])

# %%
df.head()
# Out:
#     Name  Age  Gender       City Adult  Gender_Encode
# 0    Ram   56    male     mumbai   yes              1
# 1  Shyam   12    male      delhi    no              1
# 2  Lalit   30  female   parbhani   yes              0
# 3    Raj   20    male  Banghlore   yes              1
# 4   Ramu   15  female  Banghlore    no              0

# %%
df['Adult_Encode']=le.fit_transform(df['Adult'])

# %%
df.head()
# Out:
#     Name  Age  Gender       City Adult  Gender_Encode  Adult_Encode
# 0    Ram   56    male     mumbai   yes              1             1
# 1  Shyam   12    male      delhi    no              1             0
# 2  Lalit   30  female   parbhani   yes              0             1
# 3    Raj   20    male  Banghlore   yes              1             1
# 4   Ramu   15  female  Banghlore    no              0             0

# %%
df.head()
# Out:
#     Name  Age  Gender       City Adult  Gender_Encode  Adult_Encode
# 0    Ram   56    male     mumbai   yes              1             1
# 1  Shyam   12    male      delhi    no              1             0
# 2  Lalit   30  female   parbhani   yes              0             1
# 3    Raj   20    male  Banghlore   yes              1             1
# 4   Ramu   15  female  Banghlore    no              0             0

# %%
df
# Out:
#     Name  Age  Gender       City Adult  Gender_Encode  Adult_Encode
# 0    Ram   56    male     mumbai   yes              1             1
# 1  Shyam   12    male      delhi    no              1             0
# 2  Lalit   30  female   parbhani   yes              0             1
# 3    Raj   20    male  Banghlore   yes              1             1
# 4   Ramu   15  female  Banghlore    no              0             0
# 5  Pintu   19    male      delhi   yes              1             1
# 6  Chiku   18  female     mumbai   yes              0             1

# %%
city_encoded = pd.get_dummies(df['City'], prefix='City', dtype=int)

df = pd.concat([df, city_encoded], axis=1)

# %%
df.head()
# Out:
#     Name  Age  Gender       City Adult  Gender_Encode  Adult_Encode  \
# 0    Ram   56    male     mumbai   yes              1             1
# 1  Shyam   12    male      delhi    no              1             0
# 2  Lalit   30  female   parbhani   yes              0             1
# 3    Raj   20    male  Banghlore   yes              1             1
# 4   Ramu   15  female  Banghlore    no              0             0
#
#    City_Banghlore  City_delhi  City_mumbai  City_parbhani
# 0               0           0            1              0
# 1               0           1            0              0
# 2               0           0            0              1
# 3               1           0            0              0
# 4               1           0            0              0
